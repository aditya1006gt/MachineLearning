# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# objc[54122]: Class QT_ROOT_LEVEL_POOL__THESE_OBJECTS_WILL_BE_RELEASED_WHEN_QAPP_GOES_OUT_OF_SCOPE is implemented in both /opt/anaconda3/lib/libQt6Core.6.9.2.dylib (0x15f1d0628) and /opt/anaconda3/lib/libQt5Core.5.15.2.dylib (0x17bf452e0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[54122]: Class KeyValueObserver is implemented in both /opt/anaconda3/lib/libQt6Core.6.9.2.dylib (0x15f1d0650) and /opt/anaconda3/lib/libQt5Core.5.15.2.dylib (0x17bf45308). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# ...

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
import time
time.localtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=5, tm_mday=18, tm_hour=16, tm_min=10, tm_sec=52, tm_wday=0, tm_yday=138, tm_isdst=0)

# %%
import os
os.getcwd()
# Out:
# '/Users/adi/Coding/MyAnaconda'
