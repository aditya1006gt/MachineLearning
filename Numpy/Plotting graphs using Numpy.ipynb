# %%
import numpy as np

# %%
x=np.linspace(-40,40,100)

# %%
x.size
# Out:
# 100

# %%
y=np.sin(x)

# %%
y.size
# Out:
# 100

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(x,y)

# %%
y=x*x + 2*x + 6

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(x,y)

# %%
y=np.tanh(x)

# %%
plt.plot(x,y)

# %%
y=np.cosh(x)

# %%
plt.plot(x,y)
