# %%
for i in range(1,11):
    if i == 5: 
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,11):
    if i == 5: 
        print("skipped",i)
        continue 
    print(i)
# Out:
# 1
# 2
# 3
# 4
# skipped 5
# 6
# 7
# 8
# 9
# 10

# %%
for i in range(1,11):
    pass
