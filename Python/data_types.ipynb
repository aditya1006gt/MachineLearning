# %%
# integer
print (4)
print (1e308)
print (1e309)
# Out:
# 4
# 1e+308
# inf

# %%
# float
print (4.5)
print (1.7e308)
print (1.7e309)
# Out:
# 4.5
# 1.7e+308
# inf

# %%
# boolean
print (True)
print (False)
print(0==1)
# Out:
# True
# False
# False

# %%
# complex
print (4+5j)
# Out:
# (4+5j)

# %%
# string
print('Kolkata' )
print("Kolkata")
print("""Kolkata""")
# Out:
# Kolkata
# Kolkata
# Kolkata

# %%
# list is equinvalent to array
print ([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# tuple
print ((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print ({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# dict
print({"Name": "Nitish", "Age": 30, "gender": "Male" })
# Out:
# {'Name': 'Nitish', 'Age': 30, 'gender': 'Male'}
