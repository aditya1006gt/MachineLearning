# %%
# no variable declaration
# dynamic typing
# dynamic binding a variable multiple data type to store kr payega

# %%
name = 'Hello world'
print (name)
# Out:
# Hello world

# %%
print (name)
# Out:
# Hello world

# %%
name = 1233
print (name)
# Out:
# 1233

# %%
print(name)
# Out:
# 1233

# %%
name=name+"123"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 name=name+"123"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
name="aaa"

# %%
name+="123"

# %%
print(name)
# Out:
# aaa123

# %%
# special syntax
a = 5;b=6; c=7;
print(a)
print(b);print (c)
# Out:
# 5
# 6
# 7

# %%
a,b,c =4,5,6 ;print(a);print(b);print(c)
# Out:
# 4
# 5
# 6

# %%
a = b =c =6
print (a)
print (b) 
print (c)
# Out:
# 6
# 6
# 6
