# %%
def is_even(i):
    """
    Optional docstring which tells us about the function, the... what inputs are required, what will the function return
    """
    x=i%2==0 
    return x

print(is_even(2))
# Out:
# True

# %%
def is_even(i):
    """
    Optional docstring which tells us about the function, the... what inputs are required, what will the function return
    """
    x="Even" if i%2==0 else "Odd"
    return x

print(is_even(5))
# Out:
# Odd
