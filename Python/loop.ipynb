# %%
# while
# for

print("for")
for i in range(3):
    print("aaa")

print("\nwhile")
count = 0
while count < 3:
    count += 1
    print("aaa",count)
# Out:
# for
# aaa
# aaa
# aaa
#
# while
# aaa 1
# aaa 2
# aaa 3
