# %%
print("Hello Adi, learning python") # shift + enter se output milega
# Out:
# Hello Adi, learning python

# %%
print("India", "Pakistan", "Nepal", "Srilanka")
# Out:
# India Pakistan Nepal Srilanka

# %%
print (5.6)
# Out:
# 5.6

# %%
print("India",5, True)
# Out:
# India 5 True

# %%
print() # to read documentation go inside the function(inside the bracket) and then click shift+tab

# %%
print("India", "Pakistan", "Nepal", "Srilanka",sep=',',end="\n \n \n")
# Out:
# India,Pakistan,Nepal,Srilanka
