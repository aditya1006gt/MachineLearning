# %%
# type_conversion

# %%
#implicit

# %%
4 + 5.5
# Out:
# 9.5

# %%
5 + 6+7j
# Out:
# (11+7j)

# %%
# explicit

# %%
int(4.56)
# Out:
# 4

# %%
float(3)
# Out:
# 3.0

# %%
list( 'Hello')
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
a=4.5
print(a)
# Out:
# 4.5

# %%
int(a)
# Out:
# 4

# %%
print(a)
# Out:
# 4.5

# %%
a=int(a)

# %%
print(a)
# Out:
# 4
