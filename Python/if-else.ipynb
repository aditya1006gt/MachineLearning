# %%
email = input("Apna email batao: ")
password = input("Apna password bhi batao: ")

if email == "adi@gmail.com" and password == "123456":
    print("Login successful")
elif email == "adi@gmail.com" and password != "123456":
    print("Wrong Password is incorrect")
    password = input("Apna password firse batao: ")
    if password=="123456":
        print("Welcome")
    else:
        print("Wrong Password")
else:
    print("Wrong email or password is incorrect")
# Out:
# Apna email batao:  adi@gmail.com
# Apna password bhi batao:  123455
# Apna password bhi batao:  123456
# Welcome
