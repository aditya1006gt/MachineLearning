# %%
import random
jackpot=random.randint(1,100)
count=0
a=int(input("Enter the number"))
while(a!=jackpot):
    count+=1;
    if(a>jackpot):
        print("Number is Smaller")
        a=int(input("Enter the number"))
    else :
        print("Number is Larger")
        a=int(input("Enter the number"))
print("Number found\nYour number of count is",count)
# Out:
# Enter the number 25
# Number is Larger
# Enter the number 75
# Number is Smaller
# Enter the number 50
# Number is Smaller
# Enter the number 45
# Number is Smaller
# Enter the number 35
# Number is Larger
# Enter the number 40
# Number is Larger
# Enter the number 43
# Number is Smaller
# Enter the number 42
# Number found
# Your number of count is 7
